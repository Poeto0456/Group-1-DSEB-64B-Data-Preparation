# %%
from eda_combined import *

# %%
bureau_balance = pd.read_csv(r"C:\Users\TRITON\OneDrive - National Economics University\NEU\NEU\lap trinh\Data preparation and Visualization\Final project\dseb63_final_project_DP_dataset\dseb63_final_project_DP_dataset\dseb63_bureau_balance.csv")

# %% [markdown]
# ## 1. EDA

# %%
display_dataframe_info(bureau_balance)
# Out:
# <style type="text/css">
# #T_04fc4 th {
#   background-color: #f2f2f2;
#   font-weight: bold;
#   text-align: center;
# }
# #T_04fc4_row0_col0, #T_04fc4_row0_col1, #T_04fc4_row1_col0, #T_04fc4_row1_col1, #T_04fc4_row2_col0, #T_04fc4_row2_col1, #T_04fc4_row3_col0, #T_04fc4_row3_col1 {
#   background-color: #f9f9f9;
#   color: #333;
#   border-color: #ccc;
#   text-align: left;
#   padding: 10px;
# }
# </style>
# <table id="T_04fc4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04fc4_level0_col0" class="col_heading level0 col0" >Attribute</th>
#       <th id="T_04fc4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04fc4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04fc4_row0_col0" class="data row0 col0" >Shape</td>
#       <td id="T_04fc4_row0_col1" class="data row0 col1" >Rows: 27299925
# Columns: 3</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ##### In the 3 columns of the table, there are 2 columns of numerical(int) type and 1 column of categorical(object) type.

# %%
analyze_missing_values(bureau_balance)
# Out:
# <style type="text/css">
# #T_eaba6_row0_col2, #T_eaba6_row1_col2, #T_eaba6_row2_col2 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# </style>
# <table id="T_eaba6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eaba6_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_eaba6_level0_col1" class="col_heading level0 col1" >Missing Count</th>
#       <th id="T_eaba6_level0_col2" class="col_heading level0 col2" >Missing Percentage (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eaba6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eaba6_row0_col0" class="data row0 col0" >SK_ID_BUREAU</td>
#       <td id="T_eaba6_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_eaba6_row0_col2" class="data row0 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_eaba6_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %% [markdown]
# ##### The dataset have no null values.

# %%
basic_statistics_summary(bureau_balance)
# Out:
# <style type="text/css">
# #T_1f1b3 th {
#   background-color: #f2f2f2;
#   font-weight: bold;
#   text-align: center;
# }
# #T_1f1b3_row0_col0, #T_1f1b3_row0_col1, #T_1f1b3_row0_col2, #T_1f1b3_row0_col3, #T_1f1b3_row0_col4, #T_1f1b3_row0_col5, #T_1f1b3_row0_col6, #T_1f1b3_row0_col7, #T_1f1b3_row1_col0, #T_1f1b3_row1_col1, #T_1f1b3_row1_col2, #T_1f1b3_row1_col3, #T_1f1b3_row1_col4, #T_1f1b3_row1_col5, #T_1f1b3_row1_col6, #T_1f1b3_row1_col7 {
#   background-color: #f9f9f9;
#   color: #333;
#   border-color: #ccc;
#   text-align: center;
#   padding: 10px;
# }
# </style>
# <table id="T_1f1b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f1b3_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_1f1b3_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_1f1b3_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_1f1b3_level0_col3" class="col_heading level0 col3" >min</th>
# ...

# %% [markdown]
# ## 2. EDA

# %%
visualize_cate_with_rare_and_binary(bureau_balance, 5)

# %% [markdown]
# ##### The STATUS column is categorical with values ​​from 1-5 all having proportions below 1%, values ​​C, 0, X have large proportions.

# %% [markdown]
# ## Checking outliers

# %%
checking_outlier(bureau_balance)
# Out:
# === Outlier Detection and Handling ===
# No outliers detected in column MONTHS_BALANCE.

# %% [markdown]
# ##### No outliers occur in the dataset.

# %%
low_variance(bureau_balance)
# Out:
# === Low-Variance Feature Detection ===
# c:\Users\TRITON\OneDrive - National Economics University\NEU\NEU\lap trinh\Data preparation and Visualization\Final project\data prep\eda_combined.py:322: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=numeric_cols, y=variances, palette="viridis")
# No low-variance columns detected.
# []

# %% [markdown]
# ## Heatmap

# %%
correlation_matrix(bureau_balance)
# Out:
# Strong correlations above threshold:
# No correlations found above the threshold.

# %% [markdown]
# ## Analyze numerical relationships

# %%
analyze_numeric_relationships(bureau_balance)
# Out:
# Generating pairplot for numerical variables...
