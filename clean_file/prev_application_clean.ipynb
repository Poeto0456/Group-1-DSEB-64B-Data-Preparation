# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

# %%
prev = pd.read_csv(r"C:\Users\Admin\Downloads\final_dataprep\dseb63_final_project_DP_dataset\dseb63_previous_application.csv")
prev
# Out:
#          SK_ID_PREV NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0           2030495     Consumer loans     1730.430          17145.0
# 1           1696966     Consumer loans    68258.655        1800000.0
# 2           2154916     Consumer loans    12417.390         108400.5
# 3           2802425         Cash loans    25188.615         607500.0
# 4           1536272         Cash loans    21709.125         450000.0
# ...             ...                ...          ...              ...
# 1413696     1261221     Consumer loans     6030.675         133866.0
# 1413697     1563733     Consumer loans    13726.080         137250.0
# 1413698     2319569     Consumer loans     4716.495          46800.0
# 1413699     2829648     Consumer loans    10301.940         101745.0
# 1413700     1944034         Cash loans          NaN              0.0
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 0           17145.0               0.0          17145.0
# ...

# %%
prev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1413701 entries, 0 to 1413700
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   SK_ID_PREV                   1413701 non-null  int64
#  1   NAME_CONTRACT_TYPE           1413701 non-null  object
#  2   AMT_ANNUITY                  1106483 non-null  float64
#  3   AMT_APPLICATION              1413701 non-null  float64
#  4   AMT_CREDIT                   1413700 non-null  float64
#  5   AMT_DOWN_PAYMENT             664161 non-null   float64
#  6   AMT_GOODS_PRICE              1094176 non-null  float64
#  7   WEEKDAY_APPR_PROCESS_START   1413701 non-null  object
#  8   HOUR_APPR_PROCESS_START      1413701 non-null  int64
#  9   FLAG_LAST_APPL_PER_CONTRACT  1413701 non-null  object
#  10  NFLAG_LAST_APPL_IN_DAY       1413701 non-null  int64
#  11  RATE_DOWN_PAYMENT            664161 non-null   float64
# ...

# %%
prev['NAME_CONTRACT_TYPE'].unique()
# Out:
# array(['Consumer loans', 'Cash loans', 'Revolving loans', 'XNA'],
#       dtype=object)

# %%
prev[~prev['AMT_DOWN_PAYMENT'].isna()][['AMT_ANNUITY','AMT_APPLICATION','AMT_CREDIT','AMT_DOWN_PAYMENT','AMT_GOODS_PRICE','RATE_DOWN_PAYMENT','RATE_INTEREST_PRIMARY','RATE_INTEREST_PRIVILEGED']]
# Out:
#          AMT_ANNUITY  AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  \
# 0           1730.430          17145.0     17145.0               0.0
# 1          68258.655        1800000.0   1754721.0          180000.0
# 2          12417.390         108400.5    119848.5               0.0
# 5           4830.930          47250.0     23688.0           24750.0
# 6           6664.275          71352.0     71352.0               0.0
# ...              ...              ...         ...               ...
# 1413695     3190.185          29475.0     28714.5            2947.5
# 1413696     6030.675         133866.0    133866.0               0.0
# 1413697    13726.080         137250.0    123525.0           13725.0
# 1413698     4716.495          46800.0     46800.0               0.0
# 1413699    10301.940         101745.0    112491.0               0.0
#
#          AMT_GOODS_PRICE  RATE_DOWN_PAYMENT  RATE_INTEREST_PRIMARY  \
# 0                17145.0           0.000000               0.182832
# ...

# %%
print(prev.isnull().sum()[prev.isnull().sum() > 0])
# Out:
# AMT_ANNUITY                   307218
# AMT_CREDIT                         1
# AMT_DOWN_PAYMENT              749540
# AMT_GOODS_PRICE               319525
# RATE_DOWN_PAYMENT             749540
# RATE_INTEREST_PRIMARY        1408910
# RATE_INTEREST_PRIVILEGED     1408910
# NAME_TYPE_SUITE               694672
# CNT_PAYMENT                   307213
# PRODUCT_COMBINATION              313
# DAYS_FIRST_DRAWING            561106
# DAYS_FIRST_DUE                561106
# DAYS_LAST_DUE_1ST_VERSION     561106
# DAYS_LAST_DUE                 561106
# DAYS_TERMINATION              561106
# NFLAG_INSURED_ON_APPROVAL     561106
# dtype: int64

# %%
prev[prev['NAME_TYPE_SUITE'].isna()]
# Out:
#          SK_ID_PREV NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0           2030495     Consumer loans     1730.430          17145.0
# 1           1696966     Consumer loans    68258.655        1800000.0
# 2           2154916     Consumer loans    12417.390         108400.5
# 4           1536272         Cash loans    21709.125         450000.0
# 7           2517198    Revolving loans    11250.000              0.0
# ...             ...                ...          ...              ...
# 1413689     1944678     Consumer loans    13627.665          62950.5
# 1413694     2583449         Cash loans    78879.195         337500.0
# 1413697     1563733     Consumer loans    13726.080         137250.0
# 1413699     2829648     Consumer loans    10301.940         101745.0
# 1413700     1944034         Cash loans          NaN              0.0
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 0           17145.0               0.0          17145.0
# ...

# %% [markdown]
# ## Check columns with the same amount of Nan values

# %%
prev[(prev['NAME_CONTRACT_STATUS'].isin(['Refused', 'Canceled'])) & prev['DAYS_FIRST_DUE'].isna()]
# Out:
#          SK_ID_PREV NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 1           1696966     Consumer loans    68258.655       1800000.00
# 12          1200676         Cash loans          NaN             0.00
# 14          1066767         Cash loans    44223.030        540000.00
# 17          1886446         Cash loans    19684.800        180000.00
# 18          2581058     Consumer loans    10519.965        105214.95
# ...             ...                ...          ...              ...
# 1413437     2653875         Cash loans          NaN             0.00
# 1413522     2018840     Consumer loans   102068.685        995598.00
# 1413581     2615053     Consumer loans    14593.815        174654.00
# 1413651     1478908         Cash loans          NaN             0.00
# 1413700     1944034         Cash loans          NaN             0.00
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 1         1754721.0         180000.00       1800000.00
# ...

# %%
prev[(prev['NAME_CONTRACT_STATUS'].isin(['Refused', 'Canceled'])) & prev['DAYS_FIRST_DRAWING'].isna()]
# Out:
#          SK_ID_PREV NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 1           1696966     Consumer loans    68258.655       1800000.00
# 12          1200676         Cash loans          NaN             0.00
# 14          1066767         Cash loans    44223.030        540000.00
# 17          1886446         Cash loans    19684.800        180000.00
# 18          2581058     Consumer loans    10519.965        105214.95
# ...             ...                ...          ...              ...
# 1413437     2653875         Cash loans          NaN             0.00
# 1413522     2018840     Consumer loans   102068.685        995598.00
# 1413581     2615053     Consumer loans    14593.815        174654.00
# 1413651     1478908         Cash loans          NaN             0.00
# 1413700     1944034         Cash loans          NaN             0.00
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 1         1754721.0         180000.00       1800000.00
# ...

# %%
prev[(prev['NAME_CONTRACT_STATUS'].isin(['Refused', 'Canceled'])) & prev['DAYS_LAST_DUE_1ST_VERSION'].isna()]
# Out:
#          SK_ID_PREV NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 1           1696966     Consumer loans    68258.655       1800000.00
# 12          1200676         Cash loans          NaN             0.00
# 14          1066767         Cash loans    44223.030        540000.00
# 17          1886446         Cash loans    19684.800        180000.00
# 18          2581058     Consumer loans    10519.965        105214.95
# ...             ...                ...          ...              ...
# 1413437     2653875         Cash loans          NaN             0.00
# 1413522     2018840     Consumer loans   102068.685        995598.00
# 1413581     2615053     Consumer loans    14593.815        174654.00
# 1413651     1478908         Cash loans          NaN             0.00
# 1413700     1944034         Cash loans          NaN             0.00
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 1         1754721.0         180000.00       1800000.00
# ...

# %%
prev[(prev['NAME_CONTRACT_STATUS'].isin(['Refused', 'Canceled'])) & prev['DAYS_LAST_DUE'].isna()]
# Out:
#          SK_ID_PREV NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 1           1696966     Consumer loans    68258.655       1800000.00
# 12          1200676         Cash loans          NaN             0.00
# 14          1066767         Cash loans    44223.030        540000.00
# 17          1886446         Cash loans    19684.800        180000.00
# 18          2581058     Consumer loans    10519.965        105214.95
# ...             ...                ...          ...              ...
# 1413437     2653875         Cash loans          NaN             0.00
# 1413522     2018840     Consumer loans   102068.685        995598.00
# 1413581     2615053     Consumer loans    14593.815        174654.00
# 1413651     1478908         Cash loans          NaN             0.00
# 1413700     1944034         Cash loans          NaN             0.00
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 1         1754721.0         180000.00       1800000.00
# ...

# %%
prev[(prev['NAME_CONTRACT_STATUS'].isin(['Refused', 'Canceled'])) & prev['DAYS_TERMINATION'].isna()]
# Out:
#          SK_ID_PREV NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 1           1696966     Consumer loans    68258.655       1800000.00
# 12          1200676         Cash loans          NaN             0.00
# 14          1066767         Cash loans    44223.030        540000.00
# 17          1886446         Cash loans    19684.800        180000.00
# 18          2581058     Consumer loans    10519.965        105214.95
# ...             ...                ...          ...              ...
# 1413437     2653875         Cash loans          NaN             0.00
# 1413522     2018840     Consumer loans   102068.685        995598.00
# 1413581     2615053     Consumer loans    14593.815        174654.00
# 1413651     1478908         Cash loans          NaN             0.00
# 1413700     1944034         Cash loans          NaN             0.00
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 1         1754721.0         180000.00       1800000.00
# ...

# %%
prev[(prev['NAME_CONTRACT_STATUS'].isin(['Refused', 'Canceled'])) & prev['NFLAG_INSURED_ON_APPROVAL'].isna()]
# Out:
#          SK_ID_PREV NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 1           1696966     Consumer loans    68258.655       1800000.00
# 12          1200676         Cash loans          NaN             0.00
# 14          1066767         Cash loans    44223.030        540000.00
# 17          1886446         Cash loans    19684.800        180000.00
# 18          2581058     Consumer loans    10519.965        105214.95
# ...             ...                ...          ...              ...
# 1413437     2653875         Cash loans          NaN             0.00
# 1413522     2018840     Consumer loans   102068.685        995598.00
# 1413581     2615053     Consumer loans    14593.815        174654.00
# 1413651     1478908         Cash loans          NaN             0.00
# 1413700     1944034         Cash loans          NaN             0.00
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 1         1754721.0         180000.00       1800000.00
# ...

# %% [markdown]
# ### $\rightarrow$ If the contract status is Refused or Canceled, columns such as DAYS_FIRST_DRAWING, DAYS_FIRST_DUE, DAYS_LAST_DUE_1ST_VERSION, DAYS_LAST_DUE, DAYS_TERMINATION, and NFLAG_INSURED_ON_APPROVAL (which refer to the dates of disbursement or payment) will have values of NaN.

# %%
# Exist value: 365243 which is error value
prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20412\3494792854.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20412\3494792854.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
print(prev.isnull().sum()[prev.isnull().sum() > 0])
# Out:
# AMT_ANNUITY                   307218
# AMT_CREDIT                         1
# AMT_DOWN_PAYMENT              749540
# AMT_GOODS_PRICE               319525
# RATE_DOWN_PAYMENT             749540
# RATE_INTEREST_PRIMARY        1408910
# RATE_INTEREST_PRIVILEGED     1408910
# NAME_TYPE_SUITE               694672
# CNT_PAYMENT                   307213
# PRODUCT_COMBINATION              313
# DAYS_FIRST_DRAWING           1360200
# DAYS_FIRST_DUE                595068
# DAYS_LAST_DUE_1ST_VERSION     640205
# DAYS_LAST_DUE                 741898
# DAYS_TERMINATION              755106
# NFLAG_INSURED_ON_APPROVAL     561106
# dtype: int64

# %%
prev.dropna(thresh=len(prev) * 0.4, axis='columns', inplace=True)

# %%
prev.loc[prev['AMT_CREDIT'].isnull(),'AMT_CREDIT'] = prev['AMT_APPLICATION']
prev[prev['SK_ID_PREV'] == 2204450]
# Out:
#         SK_ID_PREV NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 233370     2204450    Revolving loans          0.0              0.0
#
#         AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 233370         0.0               NaN              NaN
#
#        WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  \
# 233370                     FRIDAY                       10
#
#        FLAG_LAST_APPL_PER_CONTRACT  NFLAG_LAST_APPL_IN_DAY  RATE_DOWN_PAYMENT  \
# 233370                           Y                       1                NaN
#
#        NAME_CASH_LOAN_PURPOSE NAME_CONTRACT_STATUS  DAYS_DECISION  \
# 233370                    XAP             Approved           -608
#
#        NAME_PAYMENT_TYPE CODE_REJECT_REASON NAME_TYPE_SUITE NAME_CLIENT_TYPE  \
# 233370               XNA                XAP             NaN         Repeater
#
#        NAME_GOODS_CATEGORY NAME_PORTFOLIO NAME_PRODUCT_TYPE  CHANNEL_TYPE  \
# ...

# %%
prev.to_csv(r'C:\Users\Admin\Desktop\Final data prep\cleaned_data\prev_application.csv')

# %% [markdown]
# #### Có 3 cột bị xóa là DAYS_FIRST_DRAWING, RATE_INTEREST_PRIVILEGED, RATE_INTEREST_PRIMARY lượng null quá 90%

# %%
prev[prev['AMT_APPLICATION'] != prev['AMT_GOODS_PRICE']]
# Out:
#          SK_ID_PREV NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 7           2517198    Revolving loans      11250.0              0.0
# 12          1200676         Cash loans          NaN              0.0
# 27          1445789         Cash loans          NaN              0.0
# 33          1069859         Cash loans          NaN              0.0
# 37          1247679         Cash loans          NaN              0.0
# ...             ...                ...          ...              ...
# 1413475     1103408    Revolving loans       6750.0              0.0
# 1413551     1238888    Revolving loans       3375.0              0.0
# 1413614     1330785    Revolving loans       3375.0              0.0
# 1413651     1478908         Cash loans          NaN              0.0
# 1413700     1944034         Cash loans          NaN              0.0
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 7          225000.0               NaN              NaN
# ...

# %%
prev[(prev['AMT_APPLICATION'] !=0) & (prev['AMT_APPLICATION'] != prev['AMT_GOODS_PRICE'])]
# Out:
#          SK_ID_PREV NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 11455       1074427    Revolving loans      13500.0         135000.0
# 11456       2171166    Revolving loans      13500.0         135000.0
# 22119       1323805    Revolving loans      22500.0         765000.0
# 22120       1702411    Revolving loans      22500.0         765000.0
# 26793       1326197    Revolving loans       9000.0         270000.0
# ...             ...                ...          ...              ...
# 1322223     1396960    Revolving loans      11250.0         225000.0
# 1322229     1197086    Revolving loans      11250.0         225000.0
# 1324469     1601583    Revolving loans      18000.0         405000.0
# 1328096     1804870    Revolving loans       7875.0         450000.0
# 1382750     1408589    Revolving loans      36000.0         270000.0
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 11455      270000.0               NaN         270000.0
# ...

# %%
prev[(prev['AMT_APPLICATION'] ==0) & (prev['AMT_APPLICATION'] != prev['AMT_GOODS_PRICE'])]
# Out:
#          SK_ID_PREV NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 7           2517198    Revolving loans      11250.0              0.0
# 12          1200676         Cash loans          NaN              0.0
# 27          1445789         Cash loans          NaN              0.0
# 33          1069859         Cash loans          NaN              0.0
# 37          1247679         Cash loans          NaN              0.0
# ...             ...                ...          ...              ...
# 1413475     1103408    Revolving loans       6750.0              0.0
# 1413551     1238888    Revolving loans       3375.0              0.0
# 1413614     1330785    Revolving loans       3375.0              0.0
# 1413651     1478908         Cash loans          NaN              0.0
# 1413700     1944034         Cash loans          NaN              0.0
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 7          225000.0               NaN              NaN
# ...
